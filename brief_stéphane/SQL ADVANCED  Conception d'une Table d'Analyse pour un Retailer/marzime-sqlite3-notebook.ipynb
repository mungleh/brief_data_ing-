# %% [markdown]
# # Import

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect(':memory:')

# %%
def csv_to_sql(tablename:str):
    df = pd.read_csv(f'{tablename}.csv')
    df.to_sql(tablename, conn, if_exists='replace', index=False)

# %%
def show_tables():
    print("stores")
    print(sql("SELECT * FROM stores LIMIT 3"))
    print("products")
    print(sql("SELECT * FROM products LIMIT 3"))
    print("customers")
    print(sql("SELECT * FROM customers LIMIT 3"))
    print("transactions")
    print(sql("SELECT * FROM transactions LIMIT 3"))

# %%
csv_to_sql('stores')
csv_to_sql('products')
csv_to_sql('customers')
csv_to_sql('transactions')

# %%
sql = lambda x: pd.read_sql_query(x, conn)

# %% [markdown]
# # Exploration des Tables et Pré-Analyse

# %% [markdown]
# ## - Lister les noms des colonnes et le type de données pour chaque table.

# %%
sql("PRAGMA table_info(stores);")
# Out:
#    cid        name     type  notnull dflt_value  pk
# 0    0    store_id  INTEGER        0       None   0
# 1    1  store_name     TEXT        0       None   0
# 2    2    location     TEXT        0       None   0

# %%
sql("PRAGMA table_info(products);")
# Out:
#    cid          name     type  notnull dflt_value  pk
# 0    0    product_id  INTEGER        0       None   0
# 1    1  product_name     TEXT        0       None   0
# 2    2      category     TEXT        0       None   0
# 3    3         price     REAL        0       None   0

# %%
sql("PRAGMA table_info(customers);")
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0    customer_id  INTEGER        0       None   0
# 1    1  customer_name     TEXT        0       None   0
# 2    2            age  INTEGER        0       None   0
# 3    3         gender     TEXT        0       None   0

# %%
sql("PRAGMA table_info(transactions);")
# Out:
#    cid            name     type  notnull dflt_value  pk
# 0    0  transaction_id  INTEGER        0       None   0
# 1    1     customer_id  INTEGER        0       None   0
# 2    2      product_id  INTEGER        0       None   0
# 3    3        store_id  INTEGER        0       None   0
# 4    4            date     TEXT        0       None   0
# 5    5          amount     REAL        0       None   0

# %% [markdown]
# ## Vérifier s'il y a des doublons dans la table transactions sur la colonne transaction_id.

# %%
# calcul de l'occurence des valeurs

# %%
sql('SELECT transaction_id, COUNT(*) as count FROM transactions GROUP BY transaction_id')
# Out:
#      transaction_id  count
# 0                 1      1
# 1                 2      1
# 2                 3      1
# 3                 4      1
# 4                 5      1
# ..              ...    ...
# 995             996      1
# 996             997      1
# 997             998      1
# 998             999      1
# 999            1000      1
#
# [1000 rows x 2 columns]

# %%
# filtre des valeurs occurents plus d'une fois

# %%
sql('SELECT transaction_id, COUNT(*) as count FROM transactions GROUP BY transaction_id HAVING count > 1')
# Out:
# Empty DataFrame
# Columns: [transaction_id, count]
# Index: []

# %% [markdown]
# ## Identifier les clés primaires et les clés étrangères de chaque table.

# %%
sql("PRAGMA table_info(stores);")
# Out:
#    cid        name     type  notnull dflt_value  pk
# 0    0    store_id  INTEGER        0       None   0
# 1    1  store_name     TEXT        0       None   0
# 2    2    location     TEXT        0       None   0

# %%
sql("PRAGMA foreign_key_list('stores');")
# Out:
# Empty DataFrame
# Columns: [id, seq, table, from, to, on_update, on_delete, match]
# Index: []

# %%
sql("PRAGMA table_info(products);")
# Out:
#    cid          name     type  notnull dflt_value  pk
# 0    0    product_id  INTEGER        0       None   0
# 1    1  product_name     TEXT        0       None   0
# 2    2      category     TEXT        0       None   0
# 3    3         price     REAL        0       None   0

# %%
sql("PRAGMA foreign_key_list('products');")
# Out:
# Empty DataFrame
# Columns: [id, seq, table, from, to, on_update, on_delete, match]
# Index: []

# %%
sql("PRAGMA table_info(customers);")
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0    customer_id  INTEGER        0       None   0
# 1    1  customer_name     TEXT        0       None   0
# 2    2            age  INTEGER        0       None   0
# 3    3         gender     TEXT        0       None   0

# %%
sql("PRAGMA foreign_key_list('customers');")
# Out:
# Empty DataFrame
# Columns: [id, seq, table, from, to, on_update, on_delete, match]
# Index: []

# %%
sql("PRAGMA table_info(transactions);")
# Out:
#    cid            name     type  notnull dflt_value  pk
# 0    0  transaction_id  INTEGER        0       None   0
# 1    1     customer_id  INTEGER        0       None   0
# 2    2      product_id  INTEGER        0       None   0
# 3    3        store_id  INTEGER        0       None   0
# 4    4            date     TEXT        0       None   0
# 5    5          amount     REAL        0       None   0

# %%
sql("PRAGMA foreign_key_list('transactions');")
# Out:
# Empty DataFrame
# Columns: [id, seq, table, from, to, on_update, on_delete, match]
# Index: []

# %% [markdown]
# ## Vérifier si la colonne date dans la table transactions est stockée dans un format date, sinon, la convertir.

# %%
sql("PRAGMA table_info(transactions);")
# Out:
#    cid            name     type  notnull dflt_value  pk
# 0    0  transaction_id  INTEGER        0       None   0
# 1    1     customer_id  INTEGER        0       None   0
# 2    2      product_id  INTEGER        0       None   0
# 3    3        store_id  INTEGER        0       None   0
# 4    4            date     TEXT        0       None   0
# 5    5          amount     REAL        0       None   0

# %%
# JPEUT PAAAAAAAAAAAAAAAAAAAAAS

# %% [markdown]
# ## Vérifier s'il existe des valeurs nulles dans les colonnes customer_id, product_id, store_id des transactions.

# %%
sql("SELECT COUNT(*) as count_null_values FROM transactions WHERE customer_id + product_id + store_id IS NULL;")
# Out:
#    count_null_values
# 0                  0

# %% [markdown]
# # Requêtes de Base

# %% [markdown]
# ## Lister toutes les transactions effectuées dans les magasin de New York.

# %%
sql('SELECT * FROM stores LEFT JOIN transactions ON stores.store_id = transactions.store_id WHERE location = "New York"')
# Out:
#      store_id store_name  location  transaction_id  customer_id  product_id  \
# 0           1    Store 1  New York               7          146          78
# 1           1    Store 1  New York              12          500          81
# 2           1    Store 1  New York              29           70          52
# 3           1    Store 1  New York              51          400          62
# 4           1    Store 1  New York              76          452          29
# ..        ...        ...       ...             ...          ...         ...
# 396        20   Store 20  New York             937          104          88
# 397        20   Store 20  New York             941          370          74
# 398        20   Store 20  New York             960          497           2
# 399        20   Store 20  New York             978          292          95
# 400        20   Store 20  New York             990          399          58
#
#      store_id        date  amount
# 0           1  2023-01-07   48.99
# 1           1  2023-01-12   11.31
# 2           1  2023-01-29  290.12
# 3           1  2023-02-20  733.48
# 4           1  2023-03-17  277.07
# ..        ...         ...     ...
# 396        20  2025-07-25  905.52
# 397        20  2025-07-29  308.36
# 398        20  2025-08-17  127.38
# 399        20  2025-09-04  218.93
# 400        20  2025-09-16  514.18
#
# [401 rows x 9 columns]

# %%
# Il y a 401 eu transactions a new york

# %% [markdown]
# ## Récupérer les noms des produits achetés par le customer_id 35.

# %%
# produits achetés par le customer 35

# %%
sql('SELECT * FROM transactions WHERE customer_id = 35')
# Out:
#    transaction_id  customer_id  product_id  store_id        date  amount
# 0               1           35           8        12  2023-01-01  379.09
# 1             483           35          96         3  2024-04-27  959.61

# %%
# détails des produits achetés par le customer 35

# %%
sql('SELECT * FROM transactions LEFT JOIN products ON transactions.product_id = products.product_id WHERE customer_id = 35')
# Out:
#    transaction_id  customer_id  product_id  store_id        date  amount  \
# 0               1           35           8        12  2023-01-01  379.09
# 1             483           35          96         3  2024-04-27  959.61
#
#    product_id product_name   category   price
# 0           8    Product 8      Books  388.96
# 1          96   Product 96  Furniture  112.24

# %% [markdown]
# ## Lister les différents types de catégories de produits disponibles.

# %%
sql("SELECT DISTINCT(category) FROM products")
# Out:
#       category
# 0        Books
# 1  Electronics
# 2    Furniture
# 3     Clothing

# %% [markdown]
# ## Trouver le montant total des transactions pour le store_id 12.

# %%
sql("SELECT COUNT(*) as total_transactions_store_12 FROM transactions WHERE store_id = 12")
# Out:
#    total_transactions_store_12
# 0                           49

# %% [markdown]
# ## Lister tous les clients de sexe féminin.

# %%
sql('SELECT * FROM CUSTOMERS WHERE gender = "Female"')
# Out:
#      customer_id customer_name  age  gender
# 0              2    Customer 2   40  Female
# 1              7    Customer 7   55  Female
# 2              9    Customer 9   51  Female
# 3             10   Customer 10   22  Female
# 4             11   Customer 11   69  Female
# ..           ...           ...  ...     ...
# 226          490  Customer 490   53  Female
# 227          494  Customer 494   35  Female
# 228          496  Customer 496   59  Female
# 229          497  Customer 497   50  Female
# 230          500  Customer 500   69  Female
#
# [231 rows x 4 columns]

# %% [markdown]
# # Fonctions d’Agrégation et GROUP BY

# %% [markdown]
# ## Calculer la moyenne des montants des transactions par magasin.

# %%
sql('SELECT store_id, AVG(amount) as mean_amount_by_stores  FROM transactions GROUP BY store_id')
# Out:
#     store_id  mean_amount_by_stores
# 0          1             532.130000
# 1          2             496.529592
# 2          3             481.485789
# 3          4             563.986364
# 4          5             614.618200
# 5          6             465.471190
# 6          7             503.759412
# 7          8             461.190196
# 8          9             465.133200
# 9         10             504.817115
# 10        11             453.278361
# 11        12             546.863061
# 12        13             569.012857
# 13        14             479.562745
# 14        15             478.972679
# 15        16             493.564167
# 16        17             546.908519
# 17        18             602.175526
# 18        19             570.356531
# 19        20             496.091786

# %% [markdown]
# ## Trouver le magasin qui a réalisé le chiffre d'affaires le plus élevé.

# %%
sql('SELECT store_id, SUM(amount) as sum_amount_by_stores  FROM transactions GROUP BY store_id ORDER BY sum_amount_by_stores DESC LIMIT 1')
# Out:
#    store_id  sum_amount_by_stores
# 0         5              30730.91

# %% [markdown]
# ## Calculer le montant total dépensé par chaque client.

# %%
sql("SELECT customer_id, SUM(amount) total_spent_by_customers FROM transactions GROUP BY customer_id")
# Out:
#      customer_id  total_spent_by_customers
# 0              1                   2528.13
# 1              2                   2108.46
# 2              3                    427.58
# 3              4                   1447.50
# 4              5                    574.77
# ..           ...                       ...
# 434          496                   2437.91
# 435          497                   1821.58
# 436          498                   1672.92
# 437          499                    486.39
# 438          500                    384.58
#
# [439 rows x 2 columns]

# %% [markdown]
# ## Trouver le produit le plus vendu en termes de quantité.

# %%
sql("SELECT product_id, COUNT(*) as total_sold FROM transactions GROUP BY product_id ORDER BY total_sold DESC LIMIT 1")
# Out:
#    product_id  total_sold
# 0          45          20

# %% [markdown]
# ## Lister les catégories de produits et le montant total des ventes par catégorie.

# %%
sql("SELECT category, SUM(amount) total_amount FROM transactions t LEFT JOIN products p ON t.product_id = p.product_id GROUP BY category")
# Out:
#       category  total_amount
# 0        Books     151828.24
# 1     Clothing     108614.35
# 2  Electronics     125958.34
# 3    Furniture     127514.47

# %% [markdown]
# # Clauses HAVING vs WHERE

# %% [markdown]
# ## Lister les clients qui ont effectué plus de 5 transactions.

# %%
sql("SELECT customer_id, COUNT(*) total_transactions FROM transactions GROUP BY customer_id HAVING total_transactions > 5")
# Out:
#    customer_id  total_transactions
# 0           61                   6
# 1          141                   6
# 2          277                   6

# %% [markdown]
# ## Trouver les produits qui ont généré plus de 1000 en ventes totales.

# %%
sql("SELECT product_id, SUM(amount) total_amount FROM transactions GROUP BY product_id HAVING total_amount > 1000")
# Out:
#     product_id  total_amount
# 0            1       4334.66
# 1            2       5735.32
# 2            3       5909.48
# 3            4       3590.36
# 4            5       4182.23
# ..         ...           ...
# 95          96       6980.49
# 96          97       6947.89
# 97          98       4940.70
# 98          99       5780.27
# 99         100       2560.02
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Lister les magasins ayant une moyenne de transaction supérieure à 200.

# %%
sql("SELECT store_id, AVG(amount) average_amount FROM transactions GROUP BY store_id HAVING average_amount > 200")
# Out:
#     store_id  average_amount
# 0          1      532.130000
# 1          2      496.529592
# 2          3      481.485789
# 3          4      563.986364
# 4          5      614.618200
# 5          6      465.471190
# 6          7      503.759412
# 7          8      461.190196
# 8          9      465.133200
# 9         10      504.817115
# 10        11      453.278361
# 11        12      546.863061
# 12        13      569.012857
# 13        14      479.562745
# 14        15      478.972679
# 15        16      493.564167
# 16        17      546.908519
# 17        18      602.175526
# 18        19      570.356531
# 19        20      496.091786

# %% [markdown]
# ## Récupérer les produits appartenant à la catégorie Books et ayant généré plus de 500 en ventes.

# %%
sql("""SELECT p.product_id, category, SUM(amount) sum_amount 
        FROM transactions t 
        LEFT JOIN products p 
        ON t.product_id = p.product_id
        WHERE category = 'Books'
        GROUP BY p.product_id
        HAVING sum_amount > 500
        """)
# Out:
#     product_id category  sum_amount
# 0            1    Books     4334.66
# 1            2    Books     5735.32
# 2            3    Books     5909.48
# 3            6    Books     3147.49
# 4            8    Books     4192.44
# 5            9    Books     7749.04
# 6           14    Books     7558.51
# 7           20    Books     5097.30
# 8           31    Books     3538.25
# 9           33    Books     6547.09
# 10          39    Books     7603.02
# 11          42    Books     7611.42
# 12          47    Books     2999.79
# 13          50    Books     4482.85
# 14          52    Books     5492.80
# 15          54    Books     7047.71
# 16          55    Books     4650.90
# 17          56    Books     1982.06
# 18          61    Books     7822.99
# 19          62    Books     6269.32
# 20          65    Books     3846.50
# 21          69    Books     4718.06
# 22          72    Books     5466.35
# 23          73    Books     3885.76
# 24          79    Books     8666.74
# 25          86    Books     4495.20
# 26          94    Books     6036.49
# 27          98    Books     4940.70

# %% [markdown]
# ## Trouver les clients ayant dépensé plus de 1000 au total.

# %%
sql("SELECT customer_id, SUM(amount) sum_amount FROM transactions GROUP BY customer_id HAVING sum_amount > 1000")
# Out:
#      customer_id  sum_amount
# 0              1     2528.13
# 1              2     2108.46
# 2              4     1447.50
# 3              6     1934.12
# 4              7     1303.84
# ..           ...         ...
# 217          494     2268.27
# 218          495     1814.12
# 219          496     2437.91
# 220          497     1821.58
# 221          498     1672.92
#
# [222 rows x 2 columns]

# %% [markdown]
# # Fonctions de Manipulation de Chaînes et Dates

# %% [markdown]
# ## Extraire l’année des dates de transactions et compter le nombre de transactions par année.

# %%
sql("SELECT strftime('%Y', date) year, COUNT(*) total_transactions FROM transactions GROUP BY year")
# Out:
#    year  total_transactions
# 0  2023                 365
# 1  2024                 366
# 2  2025                 269

# %% [markdown]
# ## Concaténer le nom du client avec son âge.

# %%
sql('SELECT (customer_name || " " || age) customer_age FROM customers')
# Out:
#         customer_age
# 0      Customer 1 25
# 1      Customer 2 40
# 2      Customer 3 30
# 3      Customer 4 33
# 4      Customer 5 43
# ..               ...
# 495  Customer 496 59
# 496  Customer 497 50
# 497  Customer 498 51
# 498  Customer 499 35
# 499  Customer 500 69
#
# [500 rows x 1 columns]

# %% [markdown]
# ## Remplacer tous les espaces par des underscores dans les noms des produits.

# %%
sql("SELECT REPLACE(product_name, ' ', '_') product_name FROM products")
# Out:
#    product_name
# 0     Product_1
# 1     Product_2
# 2     Product_3
# 3     Product_4
# 4     Product_5
# ..          ...
# 95   Product_96
# 96   Product_97
# 97   Product_98
# 98   Product_99
# 99  Product_100
#
# [100 rows x 1 columns]

# %% [markdown]
# ## Transformer en majuscules les noms des magasins.

# %%
sql("SELECT UPPER(store_name) store_name FROM stores")
# Out:
#    store_name
# 0     STORE 1
# 1     STORE 2
# 2     STORE 3
# 3     STORE 4
# 4     STORE 5
# 5     STORE 6
# 6     STORE 7
# 7     STORE 8
# 8     STORE 9
# 9    STORE 10
# 10   STORE 11
# 11   STORE 12
# 12   STORE 13
# 13   STORE 14
# 14   STORE 15
# 15   STORE 16
# 16   STORE 17
# 17   STORE 18
# 18   STORE 19
# 19   STORE 20

# %% [markdown]
# # Joins

# %% [markdown]
# ## Joindre la table transactions avec stores et afficher le nom du magasin pour chaque transaction.

# %%
sql("SELECT store_name, t.* FROM transactions t LEFT JOIN stores s ON t.store_id = s.store_id")
# Out:
#     store_name  transaction_id  customer_id  product_id  store_id        date  \
# 0     Store 12               1           35           8        12  2023-01-01
# 1     Store 16               2          236          34        16  2023-01-02
# 2     Store 20               3          334          50        20  2023-01-03
# 3     Store 20               4          325          46        20  2023-01-04
# 4      Store 6               5          332          89         6  2023-01-05
# ..         ...             ...          ...         ...       ...         ...
# 995    Store 8             996          271          62         8  2025-09-22
# 996    Store 4             997          380           9         4  2025-09-23
# 997   Store 14             998           46          22        14  2025-09-24
# 998    Store 8             999            2          85         8  2025-09-25
# 999    Store 8            1000          253           4         8  2025-09-26
#
#      amount
# 0    379.09
# 1     18.48
# 2    783.51
# 3    333.82
# 4    329.74
# ..      ...
# 995  268.09
# 996  829.86
# 997  603.12
# 998  882.43
# 999  365.28
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## Joindre les tables transactions et products pour obtenir le nom du produit acheté dans chaque transaction.

# %%
sql("SELECT product_name , t.* FROM transactions t LEFT JOIN products s ON t.product_id = s.product_id")
# Out:
#     product_name  transaction_id  customer_id  product_id  store_id  \
# 0      Product 8               1           35           8        12
# 1     Product 34               2          236          34        16
# 2     Product 50               3          334          50        20
# 3     Product 46               4          325          46        20
# 4     Product 89               5          332          89         6
# ..           ...             ...          ...         ...       ...
# 995   Product 62             996          271          62         8
# 996    Product 9             997          380           9         4
# 997   Product 22             998           46          22        14
# 998   Product 85             999            2          85         8
# 999    Product 4            1000          253           4         8
#
#            date  amount
# 0    2023-01-01  379.09
# 1    2023-01-02   18.48
# 2    2023-01-03  783.51
# 3    2023-01-04  333.82
# 4    2023-01-05  329.74
# ..          ...     ...
# 995  2025-09-22  268.09
# 996  2025-09-23  829.86
# 997  2025-09-24  603.12
# 998  2025-09-25  882.43
# 999  2025-09-26  365.28
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## Faire une jointure entre transactions, products, et stores pour afficher le produit acheté, le magasin et le montant.

# %%
sql("""SELECT * 
    FROM transactions t
    LEFT JOIN products p ON t.product_id = p.product_id
    LEFT join stores s ON t.store_id = s.store_id
""")
# Out:
#      transaction_id  customer_id  product_id  store_id        date  amount  \
# 0                 1           35           8        12  2023-01-01  379.09
# 1                 2          236          34        16  2023-01-02   18.48
# 2                 3          334          50        20  2023-01-03  783.51
# 3                 4          325          46        20  2023-01-04  333.82
# 4                 5          332          89         6  2023-01-05  329.74
# ..              ...          ...         ...       ...         ...     ...
# 995             996          271          62         8  2025-09-22  268.09
# 996             997          380           9         4  2025-09-23  829.86
# 997             998           46          22        14  2025-09-24  603.12
# 998             999            2          85         8  2025-09-25  882.43
# 999            1000          253           4         8  2025-09-26  365.28
#
#      product_id product_name     category   price  store_id store_name  \
# 0             8    Product 8        Books  388.96        12   Store 12
# 1            34   Product 34  Electronics  392.02        16   Store 16
# 2            50   Product 50        Books  291.19        20   Store 20
# 3            46   Product 46     Clothing  240.86        20   Store 20
# 4            89   Product 89     Clothing  125.60         6    Store 6
# ..          ...          ...          ...     ...       ...        ...
# 995          62   Product 62        Books  183.73         8    Store 8
# 996           9    Product 9        Books  419.09         4    Store 4
# 997          22   Product 22     Clothing  203.65        14   Store 14
# 998          85   Product 85    Furniture  204.37         8    Store 8
# 999           4    Product 4  Electronics  228.15         8    Store 8
#
#         location
# 0    Los Angeles
# 1       New York
# 2       New York
# 3       New York
# 4    Los Angeles
# ..           ...
# 995      Houston
# 996     New York
# 997     New York
# 998      Houston
# 999      Houston
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Lister les transactions pour les clients de plus de 30 ans.

# %%
sql("SELECT * FROM transactions t LEFT JOIN customers c ON t.customer_id = c.customer_id WHERE age > 30")
# Out:
#      transaction_id  customer_id  product_id  store_id        date  amount  \
# 0               418            2          17        20  2024-02-22  556.39
# 1               666            2         100         3  2024-10-27  669.64
# 2               999            2          85         8  2025-09-25  882.43
# 3               446            4          93         3  2024-03-21  171.69
# 4               568            4          99         4  2024-07-21  847.98
# ..              ...          ...         ...       ...         ...     ...
# 781             345          498          60        15  2023-12-11  463.53
# 782             958          498          98         4  2025-08-15  283.84
# 783             127          499          34        10  2023-05-07  486.39
# 784              12          500          81         1  2023-01-12   11.31
# 785             604          500           5         5  2024-08-26  373.27
#
#      customer_id customer_name  age  gender
# 0              2    Customer 2   40  Female
# 1              2    Customer 2   40  Female
# 2              2    Customer 2   40  Female
# 3              4    Customer 4   33    Male
# 4              4    Customer 4   33    Male
# ..           ...           ...  ...     ...
# 781          498  Customer 498   51    Male
# 782          498  Customer 498   51    Male
# 783          499  Customer 499   35    Male
# 784          500  Customer 500   69  Female
# 785          500  Customer 500   69  Female
#
# [786 rows x 10 columns]

# %% [markdown]
# ## Lister tous les produits achetés par les clients de sexe masculin.

# %%
sql("SELECT * FROM transactions t LEFT JOIN customers c ON t.customer_id = c.customer_id WHERE gender = 'Male'")
# Out:
#      transaction_id  customer_id  product_id  store_id        date  amount  \
# 0                32            1          83         3  2023-02-01  377.15
# 1               761            1          88         1  2025-01-30  886.60
# 2               871            1          35         9  2025-05-20  649.32
# 3               965            1          89         5  2025-08-22  615.06
# 4               152            3          24         9  2023-06-01  284.59
# ..              ...          ...         ...       ...         ...     ...
# 545             370          495          33         6  2024-01-05  106.43
# 546             186          498          74         7  2023-07-05  925.55
# 547             345          498          60        15  2023-12-11  463.53
# 548             958          498          98         4  2025-08-15  283.84
# 549             127          499          34        10  2023-05-07  486.39
#
#      customer_id customer_name  age gender
# 0              1    Customer 1   25   Male
# 1              1    Customer 1   25   Male
# 2              1    Customer 1   25   Male
# 3              1    Customer 1   25   Male
# 4              3    Customer 3   30   Male
# ..           ...           ...  ...    ...
# 545          495  Customer 495   46   Male
# 546          498  Customer 498   51   Male
# 547          498  Customer 498   51   Male
# 548          498  Customer 498   51   Male
# 549          499  Customer 499   35   Male
#
# [550 rows x 10 columns]

# %% [markdown]
# # Sous-requêtes (Subqueries) et CTE

# %% [markdown]
# ## Trouver les clients qui ont effectué une transaction pour un montant supérieur à la moyenne des transactions.

# %%
sql("""
    SELECT 
        t.customer_id, 
        amount
    FROM transactions t
    LEFT JOIN customers c ON t.customer_id = c.customer_id
    WHERE amount > (
        SELECT AVG(amount) avg_amount FROM transactions
    )
""")
# Out:
#      customer_id  amount
# 0            334  783.51
# 1            379  811.79
# 2             42  515.03
# 3             28  826.28
# 4            453  888.98
# ..           ...     ...
# 497          351  934.32
# 498          189  724.74
# 499          380  829.86
# 500           46  603.12
# 501            2  882.43
#
# [502 rows x 2 columns]

# %% [markdown]
# ## Lister les produits ayant un prix supérieur au prix moyen de leur catégorie.

# %%
sql("""
    WITH a as (
        SELECT 
            category, AVG(price) avg_price
        FROM 
            products 
        GROUP BY 
            category
    )
    SELECT 
        DISTINCT 
        product_name, 
        p.category, 
        price, 
        avg_price
    FROM 
        transactions t
    LEFT JOIN products p 
        ON t.product_id = p.product_id
    LEFT JOIN a 
        ON a.category = p.category
    WHERE 
        price > avg_price
    """)
# Out:
#    product_name     category   price   avg_price
# 0     Product 2        Books  291.83  256.005714
# 1     Product 3        Books  295.06  256.005714
# 2     Product 8        Books  388.96  256.005714
# 3     Product 9        Books  419.09  256.005714
# 4    Product 14        Books  309.15  256.005714
# 5    Product 20        Books  400.85  256.005714
# 6    Product 31        Books  488.03  256.005714
# 7    Product 42        Books  361.28  256.005714
# 8    Product 47        Books  265.57  256.005714
# 9    Product 50        Books  291.19  256.005714
# 10   Product 55        Books  325.64  256.005714
# 11   Product 61        Books  456.27  256.005714
# 12   Product 65        Books  280.82  256.005714
# 13   Product 72        Books  476.81  256.005714
# 14   Product 79        Books  496.40  256.005714
# 15   Product 98        Books  412.89  256.005714
# 16   Product 11     Clothing  267.75  252.311304
# 17   Product 12     Clothing  450.63  252.311304
# 18   Product 25     Clothing  498.78  252.311304
# 19   Product 27     Clothing  404.44  252.311304
# 20   Product 40     Clothing  378.11  252.311304
# 21   Product 53     Clothing  400.67  252.311304
# 22   Product 60     Clothing  402.04  252.311304
# 23   Product 71     Clothing  408.40  252.311304
# 24   Product 77     Clothing  264.90  252.311304
# 25   Product 78     Clothing  270.15  252.311304
# 26   Product 95     Clothing  267.34  252.311304
# 27  Product 100     Clothing  352.12  252.311304
# 28   Product 10  Electronics  332.69  273.020800
# 29   Product 15  Electronics  480.60  273.020800
# 30   Product 18  Electronics  273.78  273.020800
# 31   Product 28  Electronics  488.36  273.020800
# 32   Product 30  Electronics  369.34  273.020800
# 33   Product 34  Electronics  392.02  273.020800
# 34   Product 35  Electronics  451.66  273.020800
# 35   Product 66  Electronics  481.85  273.020800
# 36   Product 74  Electronics  404.55  273.020800
# 37   Product 82  Electronics  482.74  273.020800
# 38   Product 83  Electronics  350.40  273.020800
# 39   Product 93  Electronics  484.12  273.020800
# 40    Product 5    Furniture  419.20  212.972917
# 41   Product 17    Furniture  252.33  212.972917
# 42   Product 19    Furniture  388.56  212.972917
# 43   Product 21    Furniture  229.55  212.972917
# 44   Product 29    Furniture  430.69  212.972917
# 45   Product 32    Furniture  343.67  212.972917
# 46   Product 43    Furniture  296.08  212.972917
# 47   Product 45    Furniture  332.89  212.972917
# 48   Product 57    Furniture  285.73  212.972917
# 49   Product 68    Furniture  338.24  212.972917

# %% [markdown]
# ## Utiliser un CTE pour calculer le montant total des transactions par client, puis filtrer pour trouver ceux ayant dépensé plus de 500.

# %%
sql("SELECT customer_id, SUM(amount) total_spent FROM transactions GROUP BY customer_id HAVING total_spent > 500")
# Out:
#      customer_id  total_spent
# 0              1      2528.13
# 1              2      2108.46
# 2              4      1447.50
# 3              5       574.77
# 4              6      1934.12
# ..           ...          ...
# 338          494      2268.27
# 339          495      1814.12
# 340          496      2437.91
# 341          497      1821.58
# 342          498      1672.92
#
# [343 rows x 2 columns]

# %%
sql("""
    WITH truc as (
        SELECT customer_id, SUM(amount) total_spent FROM transactions GROUP BY customer_id
    )
    SELECT c.customer_id, customer_name
    FROM customers c
    LEFT JOIN truc ON truc.customer_id = c.customer_id
    WHERE total_spent > 500
""")
# Out:
#      customer_id customer_name
# 0              1    Customer 1
# 1              2    Customer 2
# 2              4    Customer 4
# 3              5    Customer 5
# 4              6    Customer 6
# ..           ...           ...
# 338          494  Customer 494
# 339          495  Customer 495
# 340          496  Customer 496
# 341          497  Customer 497
# 342          498  Customer 498
#
# [343 rows x 2 columns]

# %% [markdown]
# ## Lister les produits qui ont été achetés plus de 10 fois et appartenant à la catégorie Electronics.

# %%
sql("""
    WITH elec_categ as (
        SELECT 
            product_id, 
            category 
        FROM 
            products 
        WHERE 
            category = "Electronics"
    )
    SELECT 
        t.product_id, 
        COUNT(*) total_sold, 
        p.category
    FROM 
        transactions t
    LEFT JOIN 
        products p ON p.product_id = t.product_id
    LEFT JOIN 
        elec_categ e ON e.product_id = p.product_id
    GROUP BY 
        t.product_id
    HAVING 
        total_sold > 10 AND 
        t.product_id = e.product_id
""")
# Out:
#    product_id  total_sold     category
# 0           7          13  Electronics
# 1          18          11  Electronics
# 2          28          11  Electronics
# 3          34          14  Electronics
# 4          35          16  Electronics
# 5          48          16  Electronics
# 6          51          13  Electronics
# 7          58          11  Electronics
# 8          74          17  Electronics

# %% [markdown]
# # Fonctions Fenêtre (Window Functions)

# %% [markdown]
# ## Attribuer un rang aux transactions en fonction du montant dans chaque magasin.

# %%
sql("""
    SELECT transaction_id, store_id, amount, RANK() OVER (PARTITION BY store_id ORDER BY amount DESC) ranking
    FROM transactions t
""")
# Out:
#      transaction_id  store_id  amount  ranking
# 0               722         1  994.80        1
# 1               415         1  975.16        2
# 2               667         1  965.60        3
# 3               203         1  936.11        4
# 4               340         1  924.09        5
# ..              ...       ...     ...      ...
# 995             452        20   95.91       52
# 996             584        20   69.02       53
# 997             598        20   49.71       54
# 998             715        20   42.45       55
# 999             630        20   24.40       56
#
# [1000 rows x 4 columns]

# %% [markdown]
# ## Calculer la somme cumulée du montant des transactions pour chaque client.

# %%
sql("""
    SELECT DISTINCT customer_id, SUM(amount) OVER (PARTITION BY customer_id) total_spent
    FROM transactions t
    ORDER BY total_spent DESC
""")
# Out:
#      customer_id  total_spent
# 0            141      5087.76
# 1            136      4087.82
# 2            476      3768.81
# 3             61      3724.36
# 4            440      3441.46
# ..           ...          ...
# 434            8        28.44
# 435          129        27.76
# 436          382        27.43
# 437          148        24.44
# 438          458        21.31
#
# [439 rows x 2 columns]

# %% [markdown]
# ## Attribuer un numéro de rang aux magasins basé sur le chiffre d'affaires total.

# %%
sql("""
    SELECT
        store_id, 
        SUM(amount) total_sales, 
        RANK() OVER (ORDER BY SUM(amount) DESC) ranking
    FROM 
        transactions
    GROUP BY 
        store_id
""")
# Out:
#     store_id  total_sales  ranking
# 0          5     30730.91        1
# 1         17     29533.06        2
# 2         19     27947.47        3
# 3         13     27881.63        4
# 4         20     27781.14        5
# 5         11     27649.98        6
# 6          3     27444.69        7
# 7         15     26822.47        8
# 8         12     26796.29        9
# 9         10     26250.49       10
# 10         7     25691.73       11
# 11         4     24815.40       12
# 12        14     24457.70       13
# 13         2     24329.95       14
# 14        16     23691.08       15
# 15         8     23520.70       16
# 16         9     23256.66       17
# 17        18     22882.67       18
# 18         1     22881.59       19
# 19         6     19549.79       20

# %% [markdown]
# ## Calculer le pourcentage de contribution de chaque transaction au total des ventes du magasin.

# %%
sql("""
    SELECT
        transaction_id,
        amount,
        store_id,
        amount * 100.0 / SUM(amount) OVER (PARTITION BY store_id) contribution_percentage,
        SUM(amount) OVER (PARTITION BY store_id) total_store_sales
    FROM
        transactions
""")
# Out:
#      transaction_id  amount  store_id  contribution_percentage  \
# 0                 7   48.99         1                 0.214102
# 1                12   11.31         1                 0.049428
# 2                29  290.12         1                 1.267919
# 3                51  733.48         1                 3.205546
# 4                76  277.07         1                 1.210886
# ..              ...     ...       ...                      ...
# 995             937  905.52        20                 3.259477
# 996             941  308.36        20                 1.109962
# 997             960  127.38        20                 0.458513
# 998             978  218.93        20                 0.788053
# 999             990  514.18        20                 1.850824
#
#      total_store_sales
# 0             22881.59
# 1             22881.59
# 2             22881.59
# 3             22881.59
# 4             22881.59
# ..                 ...
# 995           27781.14
# 996           27781.14
# 997           27781.14
# 998           27781.14
# 999           27781.14
#
# [1000 rows x 5 columns]

# %% [markdown]
# pour vérifier

# %%
sql("""
    WITH store_1 as (
    SELECT
        transaction_id,
        amount,
        store_id,
        amount * 100.0 / SUM(amount) OVER (PARTITION BY store_id) contribution_percentage,
        SUM(amount) OVER (PARTITION BY store_id) total_store_sales
    FROM
        transactions
    WHERE store_id = 1
    )
    SELECT
        SUM(contribution_percentage) sum_contribution_percentage_store_1
    FROM
        store_1
""")
# Out:
#    sum_contribution_percentage_store_1
# 0                                100.0

# %%
show_tables()
# Out:
# stores
#    store_id store_name     location
# 0         1    Store 1     New York
# 1         2    Store 2  Los Angeles
# 2         3    Store 3     New York
# products
#    product_id product_name category   price
# 0           1    Product 1    Books   14.02
# 1           2    Product 2    Books  291.83
# 2           3    Product 3    Books  295.06
# customers
#    customer_id customer_name  age  gender
# 0            1    Customer 1   25    Male
# 1            2    Customer 2   40  Female
# 2            3    Customer 3   30    Male
# transactions
#    transaction_id  customer_id  product_id  store_id        date  amount
# 0               1           35           8        12  2023-01-01  379.09
# 1               2          236          34        16  2023-01-02   18.48
# 2               3          334          50        20  2023-01-03  783.51
