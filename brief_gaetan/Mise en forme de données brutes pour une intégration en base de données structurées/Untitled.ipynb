# %%
import pandas as pd
import json
import re
import io

# %%
with open('data/darkness-dataset.txt', 'r') as file:
    data = file.read() \
                .replace(';', '')

# %%
print(data)
# Out:
# id,name,country_code,position,city,current_company,about,posts,experience,url,people_also_viewed,educations_details,education,recommendations_count,avatar,languages,certifications,recommendations,volunteer_experience,courses,followers,connections,current_company_company_id,current_company_name,publications,patents,projects,organizations,input_url,linkedin_id
# "random-id-2468,""Random Name"",""KW"","""",""Kuwait"",""{""""company_id"""":""""-seara"""",""""industry"""":""""Seara Alimentos LTDA"""",""""link"""":""""https://br.linkedin.com/company/-seara?trk=public_profile_topcard-current-company"""",""""name"""":""""Random Alimentos LTDA""""}"",""Experienced Unit Sales Manager with a demonstrated history of working in the foodâ€¦"",""[{""""attribution"""":""""By Random Name"""",""""created_at"""":""""2018-09-05T00:00:00.000Z"""",""""img"""":""""https://static.licdn.com/scds/common/u/img/pic/pic_pulse_stock_article_1.jpg"""",""""interaction"""":""""By Random Name"""",""""link"""":""""https://www.linkedin.com/pulse/hacking-linkedin-account-ahmed-nagib?trk=public_profile_article_view"""",""""title"""":""""Hacking LinkedIn Account""""}]"","""",""https://www.linkedin.com/in/random-id-2468"",""[{""""profile_link"""":""""https://kw.linkedin.com/in/moamen-yousef-147392136?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohamed-mahmoud-zaki-nakhla-24009557?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/yasser-yassin-46758626?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/raymond-haggar-57205156?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohamed-zaki-elassal-56331863?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/afif-fares-70590680?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/peter-bassil-948ba937?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohamed-alqadi-a4b47241?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohamed-sabry-e-9a6b8970?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/nasser-mahmoud-8534ba232?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/kamal-jamal-91752993?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/nabeel-rajput-84659926?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/elie-abdallah-13b280158?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://sa.linkedin.com/in/mohamed-dosouki-52424180?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/nada-bishr-115b93a4?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/firas-othman-khalil-02763879?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/islam-el-hennawi-shrm-929736100?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/hani-shahroor-08b90348?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/tuhama-laundry-a1aa91279?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/tuhama-laundry-co-b07912167?trk=public_profile_browsemap-profile""""}]"",""Alexandria University"","""","""",""https://media.licdn.com/dms/image/D4D03AQEK_J4NmphASA/profile-displayphoto-shrink_200_200/0/1711987484091?e=2147483647&v=beta&t=37e74Ho2KEQEkH0FKMYvsvKxs8fEQryzd9F2LoQpITg"",""[{""""subtitle"""":"""" Professional working proficiency """",""""title"""":"""" English """"}]"","""","""","""","""","""",500,""-seara"",""Random Alimentos LTDA"","""","""","""","""",""https://www.linkedin.com/in/random-id-2468"",""random-id-2468"" ``` &#8203:citation[oaicite:0]{index=0}&#8203"
# "random-id-1357,""Random Name"",""IN"",""Random EduTech"",""Noida, Uttar Pradesh, India"",""{""""company_id"""":""""byjus"""",""""industry"""":""""BYJU'S"""",""""link"""":""""https://in.linkedin.com/company/byjus?trk=public_profile_topcard-current-company"""",""""name"""":""""Random EduTech"""",""""title"""":""""Random EduTech""""}"","""","""",""[{""""company"""":""""Random EduTech"""",""""company_id"""":""""byjus"""",""""description_html"""":null,""""duration"""":""""Jun 2021 - Present 3 years 1 month"""",""""duration_short"""":""""3 years 1 month"""",""""end_date"""":""""Present"""",""""location"""":""""Noida, Uttar Pradesh, India"""",""""start_date"""":""""Jun 2021"""",""""title"""":""""Centre sales"""",""""url"""":""""https://in.linkedin.com/company/byjus""""},{""""company"""":""""TYSHAZ BUILDMART INDIA PRIVATE LIMITED"""",""""company_id"""":""""tyshaz-buildmart-india-private-limited"""",""""description_html"""":null,""""duration"""":""""Feb 2019 May 2021 2 years 4 months"""",""""duration_short"""":""""2 years 4 months"""",""""end_date"""":""""May 2021"""",""""location"""":""""New Delhi Area, India"""",""""start_date"""":""""Feb 2019"""",""""title"""":""""Sales Team Lead"""",""""url"""":""""https://in.linkedin.com/company/tyshaz-buildmart-india-private-limited""""}]"",""https://www.linkedin.com/in/random-id-1357"",""[{""""profile_link"""":""""https://in.linkedin.com/in/anand-kumar-pandey-b7957a82?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/sunil-bisht-b48618160?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/deep-sagar-04b953268?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://pk.linkedin.com/in/shahab-raza-186a9a288?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/amrita-singh-37820a22a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/book-falcon-544430295?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/shovit-singh-916106291?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/utkarsh-choudhary-aa7310229?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://pk.linkedin.com/in/fahad-ali-718121296?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/royalarunraj?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/amarpreet-singh-11537810b?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/rajan-kumar-77255429a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/shivam-srivastava-539678179?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/mayank-sharma-ba05b659?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/vikash-kumar-241128230?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/suman-kumar-yadav-4521b6182?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/vikram-kumar-1b78901b4?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/amit-b-a87baa1b2?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://in.linkedin.com/in/sahil-gulati-17b366200?trk=public_profile_browsemap-profile""""}]"",""Delhi University"",""[{""""degree"""":""""Bachelor's degree"""",""""description"""":null,""""description_html"""":null,""""end_year"""":""""2019"""",""""field"""":""""Marketing/Marketing Management, General"""",""""start_year"""":""""2016"""",""""title"""":""""Delhi University"""",""""url"""":""""https://in.linkedin.com/school/delhi-university/?trk=public_profile_school_profile-section-card_image-click""""}]" ...
# "random-id-8642,""Random Name"","""","""","""",""{""""company_id"""":""""shepard-exposition-services"""",""""industry"""":""""Shepard"""",""""link"""":""""https://www.linkedin.com/company/shepard-exposition-services?trk=public_profile_topcard-current-company"""",""""name"""":""""Random Event Services""""}"",""EXPERIENCED EVENT PLANNER with over three years of experience and expertise in eventâ€¦"",""[]"",""[]"",""https://www.linkedin.com/in/random-id-8642?_l=en"",""[]"",""Guilford Technical Community College"",""[]"","""",""https://media.licdn.com/dms/image/C4E03AQGGXHLvVuytJw/profile-displayphoto-shrink_200_200/0/1594763776793?e=2147483647&v=beta&t=lULMsVyPOZDTZ72EJ3Lvvuf1GKptVgHiI8iu_WBe9kw"",""[]"",""[]"",""[]"",""[]"",""[]"",190,188,""shepard-exposition-services"",""Random Event Services"",""[]"",""[]"",""[]"","""",""https://www.linkedin.com/in/random-id-8642?_l=en"",""random-id-8642"""
# "random-id-9512,""Random Name"",""UK"",""Design Engineer (System health) at Random Power Station"",""Galashiels"",""{""""company_id"""":""""edf-energy"""",""""industry"""":""""EDF (UK)"""",""""link"""":""""https://uk.linkedin.com/company/edf-energy?trk=public_profile_topcard-current-company"""",""""name"""":""""Random Power"""",""""title"""":""""Design Engineer (System health) at Random Power Station""""}"","""",""[]"",""[{""""description"""":""""Torness Nuclear Power Station, Scotland, United Kingdom"""",""""description_html"""":null,""""duration"""":""""Aug 2021 2 years 10 months"""",""""end_date"""":""""2 years 10 months"""",""""start_date"""":""""Aug 2021"""",""""subtitle"""":""""EDF (UK)"""",""""subtitleURL"""":""""https://uk.linkedin.com/company/edf-energy?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Design Engineer - System Health""""},{""""description"""":""""Torness Nuclear Power Station, Scotland, United Kingdom"""",""""description_html"""":null,""""duration"""":""""Nov 2019 Aug 2021 1 year 10 months"""",""""duration_short"""":""""1 year 10 months"""",""""end_date"""":""""Aug 2021"""",""""start_date"""":""""Nov 2019"""",""""subtitle"""":""""Risktec Solutions"""",""""subtitleURL"""":""""https://uk.linkedin.com/company/risktec-solutions?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Graduate Engineer""""},{""""description"""":""""Jedburgh"""",""""description_html"""":null,""""duration"""":""""Jul 2019 Nov 2019 5 months"""",""""duration_short"""":""""5 months"""",""""end_date"""":""""Nov 2019"""",""""start_date"""":""""Jul 2019"""",""""subtitle"""":""""Mainetti"""",""""subtitleURL"""":""""https://www.linkedin.com/company/mainetti?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Health and Safety Assistant""""},{""""description"""":""""Jedburgh My responsibilities included creating and reviewing risk assessments, updating and reviewing the company's COSHH and MSDS records for both sites in the UK. Also conducting a project to put all employees from both sites in the UK through a basic online health and safety course - this required key communication between myself and managers to organise the training to ensure production was not affected but training still got completed. I was determined to meet the deadline I was given in plenty ofâ€¦ Show more My responsibilities included creating and reviewing risk assessments, updating and reviewing the company's COSHH and MSDS records for both sites in the UK. Also conducting a project to put all employees from both sites in the UK through a basic online health and safety course - this required key communication between myself and managers to organise the training to ensure production was not affected but training still got completed. I was determined to meet the deadline I was given in plenty of time so organised to come in on different shifts to complete the training project. I am also IOSH trained Show less"""",""""description_html"""":null,""""duration"""":""""Jun 2018 Sep 2018 4 months"""",""""duration_short"""":""""4 months"""",""""end_date"""":""""Sep 2018"""",""""start_date"""":""""Jun 2018"""",""""subtitle"""":""""Mainetti"""",""""subtitleURL"""":""""https://www.linkedin.com/company/mainetti?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Health and Safety Assistant""""},{""""description"""":""""Jedburgh I have gained experience in working in different environments. This includes the importance of health and safety (risk assessment, permit to work and method statements), meeting deadlines, time management and communication. Also being reliable where the company can trust you will be at work on time on a daily basis and work overtime or under pressure to complete a job if necessary. I have been working in teams, working independently and trusted to carry out basic maintenance. Myâ€¦ Show more I ...
# "random-id-8642,""Random Name"",""KW"","""",""Kuwait"",""{""""company_id"""":""""global-infinity"""",""""industry"""":""""Global Infinity Contracting"""",""""link"""":""""https://kw.linkedin.com/company/global-infinity?trk=public_profile_topcard-current-company"""",""""name"""":""""Random Contracting""""}"",""Experienced Chief Executive Officer with a demonstrated history of working in theâ€¦"","""","""",""https://www.linkedin.com/in/random-id-8642"",""[{""""profile_link"""":""""https://kw.linkedin.com/in/mazen-sahyouni-b281732a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/abdallah-khazaal-094161106?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mostafa-bersy-20135228?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohammed-khorsheed-a9925a30?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://sa.linkedin.com/in/abudurrah?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohammed-boodai-b79b4888?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohammed-ali-9506214a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/talal-alyahya-a13a05134?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/ahmedalmazeedi?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://eg.linkedin.com/in/ahmed-elsewedy-a16132194?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/haitham-al-anjari?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/nadia-al-mousawi-159192b?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/fadi-kheder-4839b75?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://sa.linkedin.com/in/wassim-hamdanieh-6b8185a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/muhammad-atef-afifi-436a2952?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/dr-reham-alraghaib-92aa9799?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/ahmad-alotaibi-19516165?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/hamad-al-marzouq-4956146?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/drziaahmed?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mona-hamouda-39b451109?trk=public_profile_browsemap-profile""""}]"",""Cairo University"","""","""",""https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"",""[{""""subtitle"""":"""" Professional working proficiency """",""""title"""":"""" English """"},{""""subtitle"""":"""" Native or bilingual proficiency """",""""title"""":"""" Arabic """"}]"","""","""","""","""","""",500,""global-infinity"",""Random Contracting"","""","""","""","""",""https://www.linkedin.com/in/random-id-8642"",""random-id-8642"""
# "random-id-7531,""Random Name"",""KW"","""",""Kuwait"",""{""""company_id"""":""""global-infinity"""",""""industry"""":""""Global Infinity Contracting"""",""""link"""":""""https://kw.linkedin.com/company/global-infinity?trk=public_profile_topcard-current-company"""",""""name"""":""""Random Contracting""""}"",""Experienced Chief Executive Officer with a demonstrated history of working in theâ€¦"","""","""",""https://www.linkedin.com/in/random-id-7531"",""[{""""profile_link"""":""""https://kw.linkedin.com/in/mazen-sahyouni-b281732a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/abdallah-khazaal-094161106?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mostafa-bersy-20135228?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohammed-khorsheed-a9925a30?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://sa.linkedin.com/in/abudurrah?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohammed-boodai-b79b4888?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mohammed-ali-9506214a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/talal-alyahya-a13a05134?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/ahmedalmazeedi?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://eg.linkedin.com/in/ahmed-elsewedy-a16132194?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/haitham-al-anjari?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/nadia-al-mousawi-159192b?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/fadi-kheder-4839b75?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://sa.linkedin.com/in/wassim-hamdanieh-6b8185a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/muhammad-atef-afifi-436a2952?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/dr-reham-alraghaib-92aa9799?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/ahmad-alotaibi-19516165?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/hamad-al-marzouq-4956146?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/drziaahmed?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/mona-hamouda-39b451109?trk=public_profile_browsemap-profile""""}]"",""Cairo University"","""","""",""https://static.licdn.com/aero-v1/sc/h/9c8pery4andzj6ohjkjp54ma2"",""[{""""subtitle"""":"""" Professional working proficiency """",""""title"""":"""" English """"},{""""subtitle"""":"""" Native or bilingual proficiency """",""""title"""":"""" Arabic """"}]"","""","""","""","""","""",500,""global-infinity"",""Random Contracting"","""","""","""","""",""https://www.linkedin.com/in/random-id-7531"",""random-id-7531"""
# "random-id-7890,""Random Name"",""DZ"",""Logging Operations & Petrophysical QA/QC supervisor (coordinator)"",""Biskra, Algeria"",""{""""industry"""":""""None at present"""",""""name"""":""""None at present"""",""""title"""":""""Logging Operations & Petrophysical QA/QC supervisor (coordinator)""""}"",""I have fifteen years of experience in the oil and gas industry and I'm currently looking for a great challenge to evolve in a diversified position, not only in selection but also in other.<br>IÂ´m also looking for a company which will give me the opportunity to have an interesting career ..<br>Looking for new challenges<br>contact me: randomemail@Gmail.com<br><br>â€¢Logging Operation Supervisor in (Vertical, Deviated and Horizontal Wells) including basic Open hole and Cased hole operations, well integrity, high technology services (Wireline Formation Tester, NMR, Imaging, Pulsed Neutron spectroscopy), and Work over operations. <br>â€¢"Discuss High Technology Logging Operation PreJob modeling (NMR, ECS, FLEXâ€¦.)<br>â€¢Well site Data QC Quality Control.<br>â€¢Open hole Standard and Advanced Formation Evaluation.<br>â€¢"Perforation Programs"""","""""""",""""[{""""company"""":""""None at present"""",""""description"""":""""legal consultant at the Supreme Court of Algeria"""",""""description_html"""":""""legal consultant at the Supreme Court of Algeria <!---->"""""",""""duration"""":""""Oct 2012 - Present 11 years 8 months"""",""""duration_short"""":""""11 years 8 months"""",""""end_date"""":""""Present"""",""""location"""":""""biskra"""",""""start_date"""":""""Oct 2012"""",""""title"""":""""Retired""""},{""""company"""":""""Sonatrach"""",""""company_id"""":""""sonatrach"""",""""description_html"""":null,""""duration"""":""""Jun 1976 Jan 2011 34 years 8 months"""",""""duration_short"""":""""34 years 8 months"""",""""end_date"""":""""Jan 2011"""",""""location"""":""""SAHARA /Hassi Messaoud"""",""""start_date"""":""""Jun 1976"""",""""title"""":""""QA/QC Logging OH/CH Supervisor"""",""""url"""":""""https://dz.linkedin.com/company/sonatrach""""}]"""",""https://dz.linkedin.com/in/random-id-7890"",""[{""""profile_link"""":""""https://dz.linkedin.com/in/khaled-chadli-56949944?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://dz.linkedin.com/in/hans-klampferer-5b729847?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://dz.linkedin.com/in/boudjema-hadj-chaib-a7734b89?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://dz.linkedin.com/in/samira-belkhiri-b31774112?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://kw.linkedin.com/in/sonia-rashid-090617153?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://dz.linkedin.com/in/arezki-sahnoune-9877608b?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://dz.linkedin.com/in/hasnaoui-mohammed-4a349783?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://bo.linkedin.com/in/diego-juan-pozo-reynaga-384168119?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://fr.linkedin.com/in/djaffar-si-hassen-27a18629?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://uk.linkedin.com/in/ian-kenny-7b38b558?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://dz.linkedin.com/in/amir-sadou-9b6100139?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://dz.linkedin.com/in/boutouil-ammar?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://eg.linkedin.com/in/nessreen-ezzat-a12ba780?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://dz.linkedin.com/in/rory-miller-5a941216?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ae.linkedin.com/in/farook-maharaj-iqbal-16a120236?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://dz.linkedin.com/in/hamza-teniou-b750b214a?trk= ...
# "random-id-4820,""Random Name"",""NG"",""Volkswagen Product at Random Auto Sales"",""Nigeria"",""{""""industry"""":""""CollinsCAR-Automobile_inv.org"""",""""name"""":""""Random Auto Sales"""",""""title"""":""""Volkswagen Product at Random Auto Sales""""}"",""We encourage you to browse our online inventory, schedule a test drive and investigate financing options. Keeping customers satisfied is our focus in selling you all your favorite brands names, click on our usedÂ  Volkswagen, Passat, Bora, Golf, skoda, Audi, SEAT, Vanagon...<br>We stand behind our vehicles and provide warranty. Allow us to demonstrate our commitment to excellence!<br>U may visite collinscar facebook fan page for more details<br>https://m.facebook.com/profile.php?id=720821084660300"",""[{""""attribution"""":""""By Random Name"""",""""created_at"""":""""2015-05-18T00:00:00.000Z"""",""""img"""":""""https://media.licdn.com/dms/image/C5112AQFNVWwIUz0eQA/article-cover_image-shrink_600_2000/0/1520207342213?e=2147483647&v=beta&t=vxJ8F2oIRIHriBBbQ0OPqgaMTn1vDgPSSgBZPdGsP-U"""",""""interaction"""":null,""""link"""":""""https://www.linkedin.com/pulse/welcome-collins-car-sales-osinachi-obaji?trk=public_profile_article_view"""",""""title"""":""""WELCOME TO COLLINS CAR SALES""""}]"",""[{""""company"""":""""Random Auto Sales"""",""""description_html"""":null,""""title"""":""""Volkswagen Product""""}]"",""https://www.linkedin.com/in/random-id-4820"",""[{""""profile_link"""":""""https://ng.linkedin.com/in/taiwo-daniel-aa9b15194?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/agunu-victor-9228701b0?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/joseph-temidayo-adeniyi?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/olamide-joseph-oladokun-753a331a0?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://www.linkedin.com/in/gbolahan-ayomide-a65957197?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/oyeleke-ayooluwa-284691194?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/abdulbaqeeh-hassan-8ab3b393?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/usman-mariam-6934a77a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/olawale-yusuf-esilokun-987732191?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://za.linkedin.com/in/christabell-dzinoreva-199bb81ab?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/mubarak-babatunde-66462418b?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/david-akapo-633906128?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/ajayi-oluwafemi-james-b3b334184?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/olalekansannim?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/daniel-obuebhor-430542193?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/azeez-wasiu-164650199?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/kabiawu-mutiu-lasbat-1b196718a?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/afolashade-oyegbade-a09064171?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/triptsen-760653179?trk=public_profile_browsemap-profile""""},{""""profile_link"""":""""https://ng.linkedin.com/in/seun-gbenga-a001a1188?trk=public_profile_browsemap-profile""""}]"",""Advance Auto Engineering"",""[{""""degree"""":""""master degree of junior"""",""""description"""":null,""""description_html"""":null,""""title" ...
# "random-id-9025,""Random Name"",""UK"","""","""",""{""""company_id"""":""""oldmill"""",""""industry"""":""""Old Mill"""",""""link"""":""""https://uk.linkedin.com/company/oldmill?trk=public_profile_topcard-current-company"""",""""name"""":""""Random Company""""}"",""I have worked in Financial Services since late 1999.<br><br>Over this time I haveâ€¦"",""[]"",""[]"",""https://www.linkedin.com/in/random-id-9025?_l=en"",""[]"",""University of Exeter"",""[]"","""",""https://media.licdn.com/dms/image/D4D03AQGJiEdTxbK1MQ/profile-displayphoto-shrink_200_200/0/1707397877464?e=2147483647&v=beta&t=3-aMXB-NiXhMKkzB85mpUHX1n8t8xP-DQZGGZsHn1jA"",""[]"",""[]"",""[]"",""[]"",""[]"",739,500,""oldmill"",""Random Company"",""[]"",""[]"",""[{},{}]"","""",""https://www.linkedin.com/in/random-id-9025"",""random-id-9025"""
# "random-id-5837,""Random Name"",""EG"",""Food Safety & hygiene coordinator at Random Hotels Group & Random Alcazar South Sinai"",""Cairo"",""{""""company_id"""":""""steigenberger"""",""""industry"""":""""Steigenberger Hotels and Resorts"""",""""link"""":""""https://de.linkedin.com/company/steigenberger?trk=public_profile_topcard-current-company"""",""""name"""":""""Random Hotels and Resorts"""",""""title"""":""""Food Safety & hygiene coordinator at Random Hotels Group & Random Alcazar South Sinai""""}"","""",""[]"",""[{""""description"""":""""Ø¬Ù†ÙˆØ¨ Ø³ÙŠÙ†Ø§Ø¡ Ø´Ø±Ù… Ø§Ù„Ø´ÙŠØ® Ù…ØµØ±"""",""""description_html"""":null,""""duration"""":""""Oct 2023 8 months"""",""""end_date"""":""""8 months"""",""""start_date"""":""""Oct 2023"""",""""subtitle"""":""""Random Hotels and Resorts"""",""""subtitleURL"""":""""https://de.linkedin.com/company/steigenberger?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Food safety and hygiene coordinator""""},{""""description"""":""""Ù…ØµØ±"""",""""description_html"""":null,""""duration"""":""""Mar 2023 Oct 2023 8 months"""",""""duration_short"""":""""8 months"""",""""end_date"""":""""Oct 2023"""",""""start_date"""":""""Mar 2023"""",""""subtitle"""":""""AHDO"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/ahdo?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Food Safety Specialist""""},{""""description"""":""""Cairo, Egypt"""",""""description_html"""":null,""""duration"""":""""Oct 2022 Feb 2023 5 months"""",""""duration_short"""":""""5 months"""",""""end_date"""":""""Feb 2023"""",""""start_date"""":""""Oct 2022"""",""""subtitle"""":""""BIOMED Pharmaceuticals"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/biomed-pharmaceutical-plants?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Medical Sales Representative""""},{""""description"""":""""Cairo, Egypt"""",""""description_html"""":null,""""duration"""":""""Jul 2022 Oct 2022 4 months"""",""""duration_short"""":""""4 months"""",""""end_date"""":""""Oct 2022"""",""""start_date"""":""""Jul 2022"""",""""subtitle"""":""""Flamingo Hyper Market"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/flamingo-hyper-market?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Quality Assurance Quality Control""""},{""""description"""":""""Cairo, Egypt"""",""""description_html"""":null,""""duration"""":""""Jul 2022 Oct 2022 4 months"""",""""duration_short"""":""""4 months"""",""""end_date"""":""""Oct 2022"""",""""start_date"""":""""Jul 2022"""",""""subtitle"""":""""AHDO"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/ahdo?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Internship Trainee""""},{""""description_html"""":null,""""duration"""":""""Aug 2021 Aug 2021 1 month"""",""""duration_short"""":""""1 month"""",""""end_date"""":""""Aug 2021"""",""""start_date"""":""""Aug 2021"""",""""subtitle"""":""""Egyptian Veterinarians Syndicate"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/egyptian-veterinarians-syndicate?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Internship Trainee""""},{""""description_html"""":null,""""duration"""":""""Aug 2021 Aug 2021 1 month"""",""""duration_short"""":""""1 month"""",""""end_date"""":""""Aug 2021"""",""""start_date"""":""""Aug 2021"""",""""subtitle"""":""""UCA - UPgrade Consulting Agency"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/upgrade-consulting-agency?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Internship Trainee""""},{""""description"""":""""Cairo, Egypt"""",""""description_html"""":null,""""duration"""":""""Jun 2018 Oct 2018 5 months"""",""""duration_short"""":""""5 months"""",""""end_date"""":""""Oct 2018"""",""""start_date"""":""""Jun 2018""""," ...
# "random-id-5847,""Random Name"",""GB"",""Community Associate at Random Labs Cambridge"",""Greater Cambridge Area"",""{""""industry"""":""""Random Labs"""",""""name"""":""""Random Labs"""",""""title"""":""""Community Associate at Random Labs Cambridge""""}"",""Experienced in hospitality with a demonstrated history of working in the events industry. Skilled in Project Estimation, Conference Services, Customer Relationship Management (CRM), Account Management, and Contract Management. Strong community and social services professional."","""",""[{""""company"""":""""Random Labs"""",""""description"""":""""As Community Associate I am the primary point of contact for the community and act as the â€œfaceâ€ of Random Labs, Cambridge."""",""""description_html"""":""""As Community Associate I am the primary point of contact for the community and act as the â€œfaceâ€ of Random Labs, Cambridge. <!---->"""",""""duration"""":""""Jul 2016 - Present 7 years 11 months"""",""""duration_short"""":""""7 years 11 months"""",""""end_date"""":""""Present"""",""""location"""":""""Cambridge, United Kingdom"""",""""start_date"""":""""Jul 2016"""",""""title"""":""""Community Associate""""},{""""company"""":""""The Cambridge Crystallographic Data Centre"""",""""company_id"""":""""cambridge-crystallographic-data-centre"""",""""description_html"""":null,""""duration"""":""""Apr 2015 Jul 2016 1 year 4 months"""",""""duration_short"""":""""1 year 4 months"""",""""end_date"""":""""Jul 2016"""",""""location"""":""""Cambridge, United Kingdom"""",""""start_date"""":""""Apr 2015"""",""""title"""":""""Sales Administrator"""",""""url"""":""""https://uk.linkedin.com/company/cambridge-crystallographic-data-centre""""},{""""company"""":""""Clear Glass (Cambridge) Ltd"""",""""description"""":""""Clear Glass is a small business located in the centre of Cambridge. Covering both Domestic & Commercial projects, all aspects of glass and glazing are covered.Customer Service and Project Management are my key rolls within the company. Being the first (and often last) point of contact for the business requires excellent communication skills in which I excel. Ensuring clients are happy with their projects from start to finish, addressing any concerns and putting their minds at ease should any issues arise is all part of my practice. Thorough due diligence and attention to detail is required at all stages on any projects I work on: liaising with clients on their initial enquires, gathering prices & order processing, quality control and ensuring all products are up to the safety standard for its intended usage.I also do all the administrative tasks involved in the day to day running of the office.Past Projects:Restoration of Stained Glass Panels - Main Hall, Guildhall CambridgeKitchen Glass Splashbacks - Riverside Apartments, Cambridge"""",""""description_html"""":""""Clear Glass is a small business located in the centre of Cambridge. Covering both Domestic &amp" Commercial projects, all aspects of glass and glazing are covered.<br>Customer Service and Project Management are my key rolls within the company. Being the first (and often last) point of contact for the business requires excellent communication skills in which I excel. Ensuring clients are happy with their projects from start to finish, addressing any concerns and putting their minds at ease should any issues arise is all part of my practice. Thorough due diligence and attention to detail is required at all stages on any projects I work on: liaising with clients on their initial enquires, gathering prices &amp" order processing, quality control and ensuring all products are up to the safety standard for its intended usage.<br>I also do all the administrative tasks involved in the day to day running of the office.<br>Past Projects:<br>Restoration of Stained Glass Panels - Main Hall, Guildhall Cambridge<br>Kitchen Glass Splashbacks - Riverside Apartments, Cambridge"""",""""duration"""":""""Aug 2012 Apr 2015 2 years 9 mo ...
# "random-id-12286a197,""Random Name"",""EG"",""Senior Media Buyer | Marketing Strategist | Google Ads | Meta Ads | E-commerce | Growth Marketing | Lead Generation | SEM | PPC"",""New Cairo"",""{""""company_id"""":""""cmg-city-mega-group"""",""""industry"""":""""CMG | City Mega Group"""",""""link"""":""""https://eg.linkedin.com/company/cmg-city-mega-group?trk=public_profile_topcard-current-company"""",""""name"""":""""CMG | City Mega Group"""",""""title"""":""""Senior Media Buyer | Marketing Strategist | Google Ads | Meta Ads | E-commerce | Growth Marketing | Lead Generation | SEM | PPC""""}"",""I've spent 3 years optimizing campaigns and crafting compelling ad strategies to help businesses achieve their social media marketing goals in industries like (Food - Health - Medical - Beauty - Fashion - electronics, technology - Real Estate - Manufacturing - Marketing agencies) and others."",""[]"",""[{""""description"""":""""Cairo, Egypt"""",""""description_html"""":null,""""duration"""":""""Feb 2024 May 2024 4 months"""",""""duration_short"""":""""4 months"""",""""end_date"""":""""May 2024"""",""""start_date"""":""""Feb 2024"""",""""subtitle"""":""""CMG | City Mega Group"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/cmg-city-mega-group?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Senior Media Buyer""""},{""""description"""":""""Cairo, Egypt"""",""""description_html"""":null,""""duration"""":""""Jan 2024 Apr 2024 4 months"""",""""duration_short"""":""""4 months"""",""""end_date"""":""""Apr 2024"""",""""start_date"""":""""Jan 2024"""",""""subtitle"""":""""BloomPack"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/bloompackcarton?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Social Media Specialist""""},{""""description"""":""""Saudi Arabia"""",""""description_html"""":null,""""duration"""":""""Oct 2023 Apr 2024 7 months"""",""""duration_short"""":""""7 months"""",""""end_date"""":""""Apr 2024"""",""""start_date"""":""""Oct 2023"""",""""subtitle"""":""""Riyadh Review of Books"""",""""subtitleURL"""":""""https://sa.linkedin.com/company/riyadhreviewbooks?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Search Engine Optimization Specialist""""},{""""description"""":""""Qesm El Maadi, Cairo, Egypt"""",""""description_html"""":null,""""duration"""":""""Mar 2023 Apr 2024 1 year 2 months"""",""""duration_short"""":""""1 year 2 months"""",""""end_date"""":""""Apr 2024"""",""""start_date"""":""""Mar 2023"""",""""subtitle"""":""""GORILLA STUDIO"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/gorilla-studio-official?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Media Buyer""""},{""""description"""":""""Al Fayyum, Egypt"""",""""description_html"""":null,""""duration"""":""""Jan 2021 Oct 2023 2 years 10 months"""",""""duration_short"""":""""2 years 10 months"""",""""end_date"""":""""Oct 2023"""",""""start_date"""":""""Jan 2021"""",""""subtitle"""":""""IEEE Fayoum Student Branch"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/ieeefsb?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Marketing Team Member""""},{""""description"""":""""Egypt Web Development, Email Marketing, Social media Marketing, Inbound Marketing Strategy, Content Creation, Copywriting, Media Buying, and Brand Management."""",""""description_html"""":null,""""duration"""":""""Jan 2019 Dec 2022 4 years"""",""""duration_short"""":""""4 years"""",""""end_date"""":""""Dec 2022"""",""""start_date"""":""""Jan 2019"""",""""subtitle"""":""""bab al-sirr"""",""""subtitleURL"""":""""https://eg.linkedin.com/company/bab-al-sirr?trk=public_profile_experience-item_profile-section-card_subtitle-click"""",""""title"""":""""Marketing Manager""""}]"",""https://www.linkedin.com/in/random-id-12286a197"",""[]"",""Beni-Suef Univers ...

# %%
df = pd.read_csv(io.StringIO(data), sep="|")
df
# Out:
#    id,name,country_code,position,city,current_company,about,posts,experience,url,people_also_viewed,educations_details,education,recommendations_count,avatar,languages,certifications,recommendations,volunteer_experience,courses,followers,connections,current_company_company_id,current_company_name,publications,patents,projects,organizations,input_url,linkedin_id
# 0   random-id-2468,"Random Name","KW","","Kuwait",...
# 1   random-id-1357,"Random Name","IN","Random EduT...
# 2   random-id-8642,"Random Name","","","","{""comp...
# 3   random-id-9512,"Random Name","UK","Design Engi...
# 4   random-id-8642,"Random Name","KW","","Kuwait",...
# 5   random-id-7531,"Random Name","KW","","Kuwait",...
# 6   random-id-7890,"Random Name","DZ","Logging Ope...
# 7   random-id-4820,"Random Name","NG","Volkswagen ...
# 8   random-id-9025,"Random Name","UK","","","{""co...
# 9   random-id-5837,"Random Name","EG","Food Safety...
# 10  random-id-5847,"Random Name","GB","Community A...
# 11  random-id-12286a197,"Random Name","EG","Senior...

# %%
col_name = df.columns[0].split(",")

# %%
col_name
# Out:
# ['id',
#  'name',
#  'country_code',
#  'position',
#  'city',
#  'current_company',
#  'about',
#  'posts',
#  'experience',
#  'url',
#  'people_also_viewed',
#  'educations_details',
#  'education',
#  'recommendations_count',
#  'avatar',
#  'languages',
#  'certifications',
#  'recommendations',
#  'volunteer_experience',
#  'courses',
#  'followers',
#  'connections',
#  'current_company_company_id',
#  'current_company_name',
#  'publications',
#  'patents',
#  'projects',
#  'organizations',
#  'input_url',
#  'linkedin_id']

# %%
troc = df['id,name,country_code,position,city,current_company,about,posts,experience,url,people_also_viewed,educations_details,education,recommendations_count,avatar,languages,certifications,recommendations,volunteer_experience,courses,followers,connections,current_company_company_id,current_company_name,publications,patents,projects,organizations,input_url,linkedin_id']

# %%
# lal = re.split(r'(?!{.*),(?!.*})', troc[0])

# %%
troc
# Out:
# 0     random-id-2468,"Random Name","KW","","Kuwait",...
# 1     random-id-1357,"Random Name","IN","Random EduT...
# 2     random-id-8642,"Random Name","","","","{""comp...
# 3     random-id-9512,"Random Name","UK","Design Engi...
# 4     random-id-8642,"Random Name","KW","","Kuwait",...
# 5     random-id-7531,"Random Name","KW","","Kuwait",...
# 6     random-id-7890,"Random Name","DZ","Logging Ope...
# 7     random-id-4820,"Random Name","NG","Volkswagen ...
# 8     random-id-9025,"Random Name","UK","","","{""co...
# 9     random-id-5837,"Random Name","EG","Food Safety...
# 10    random-id-5847,"Random Name","GB","Community A...
# 11    random-id-12286a197,"Random Name","EG","Senior...
# Name: id,name,country_code,position,city,current_company,about,posts,experience,url,people_also_viewed,educations_details,education,recommendations_count,avatar,languages,certifications,recommendations,volunteer_experience,courses,followers,connections,current_company_company_id,current_company_name,publications,patents,projects,organizations,input_url,linkedin_id, dtype: object
