# %% [markdown]
# # Import

# %%
import matplotlib as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('cli_ven_psc.csv', delimiter=",")

# %%
df['date'] = df['date'].astype('datetime64[ns]')

# %%
df
# Out:
#        client_id  sex   birth product_id                       date  \
# 0         c_4410    f  1967.0     0_1455 2021-03-22 14:29:25.189266
# 1         c_4389    m  1984.0     0_1455 2021-07-09 11:16:18.579726
# 2         c_5019    f  1977.0     0_1455 2022-01-15 00:01:53.456196
# 3         c_7049    f  1987.0     0_1455 2021-03-04 14:01:38.698752
# 4         c_5110    f  1982.0     0_1455 2021-09-05 11:48:41.065009
# ...          ...  ...     ...        ...                        ...
# 337314       NaN  NaN     NaN      0_525                        NaT
# 337315       NaN  NaN     NaN       2_86                        NaT
# 337316       NaN  NaN     NaN      0_299                        NaT
# 337317       NaN  NaN     NaN      0_510                        NaT
# 337318       NaN  NaN     NaN     0_2308                        NaT
#
#        session_id  quantity_sold   category        sub_category   price  \
# 0          s_9942           10.0  Vêtements            T-shirts    8.99
# ...

# %% [markdown]
# # EDA tavu

# %%
df_time = df.copy()

# %%
df_time['date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [58], line 1
# ----> 1 df_time['date'].dt.year
#
# File ~/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
df_time
# Out:
#        client_id  sex   birth product_id    date session_id  quantity_sold  \
# 0         c_4410    f  1967.0     0_1455  2021.0     s_9942           10.0
# 1         c_4389    m  1984.0     0_1455  2021.0    s_59967            2.0
# 2         c_5019    f  1977.0     0_1455  2022.0   s_149928            1.0
# 3         c_7049    f  1987.0     0_1455  2021.0     s_1637            5.0
# 4         c_5110    f  1982.0     0_1455  2021.0    s_85364            4.0
# ...          ...  ...     ...        ...     ...        ...            ...
# 337314       NaN  NaN     NaN      0_525     NaN        NaN            0.0
# 337315       NaN  NaN     NaN       2_86     NaN        NaN            0.0
# 337316       NaN  NaN     NaN      0_299     NaN        NaN            0.0
# 337317       NaN  NaN     NaN      0_510     NaN        NaN            0.0
# 337318       NaN  NaN     NaN     0_2308     NaN        NaN            0.0
#
#          category        sub_category   price  stock_quantity
# ...

# %%
sns.countplot(data=df, y="date",palette='pastel')
# Out:
# <AxesSubplot:xlabel='count', ylabel='date'>
