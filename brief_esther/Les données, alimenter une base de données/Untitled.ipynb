# %%
import json

# %%
f = open('data/json/clients.json')

# %%
# returns JSON object as a dictionary
data = json.load(f)

# %%
data
# Out:
# [{'client_id': 'c_4450', 'sex': 'f', 'birth': '1977'},
#  {'client_id': 'c_277', 'sex': 'f', 'birth': '2000'},
#  {'client_id': 'c_4270', 'sex': 'f', 'birth': '1979'},
#  {'client_id': 'c_4597', 'sex': 'm', 'birth': '1963'},
#  {'client_id': 'c_1242', 'sex': 'f', 'birth': '1980'},
#  {'client_id': 'c_2526', 'sex': 'f', 'birth': '1982'},
#  {'client_id': 'c_5799', 'sex': 'f', 'birth': '1962'},
#  {'client_id': 'c_1422', 'sex': 'f', 'birth': '1980'},
#  {'client_id': 'c_2207', 'sex': 'f', 'birth': '1970'},
#  {'client_id': 'c_5433', 'sex': 'f', 'birth': '1981'},
#  {'client_id': 'c_2225', 'sex': 'f', 'birth': '1949'},
#  {'client_id': 'c_220', 'sex': 'm', 'birth': '1960'},
#  {'client_id': 'c_857', 'sex': 'm', 'birth': '1985'},
#  {'client_id': 'c_2828', 'sex': 'f', 'birth': '1987'},
#  {'client_id': 'c_648', 'sex': 'm', 'birth': '1976'},
#  {'client_id': 'c_7099', 'sex': 'f', 'birth': '1971'},
#  {'client_id': 'c_611', 'sex': 'f', 'birth': '1987'},
# ...

# %%
data[0].keys()
# Out:
# dict_keys(['client_id', 'sex', 'birth'])

# %%
df = pd.json_normalize(data)

# %%
df
# Out:
#        client_id sex birth
# 0         c_4450   f  1977
# 1          c_277   f  2000
# 2         c_4270   f  1979
# 3         c_4597   m  1963
# 4         c_1242   f  1980
# ...          ...  ..   ...
# 336483    c_3454   m  1969
# 336484    c_6268   m  1991
# 336485    c_4137   f  1968
# 336486       c_5   f  1994
# 336487    c_6714   f  1968
#
# [336488 rows x 3 columns]
